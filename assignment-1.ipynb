# %% [markdown]
# # Assignment 1: Spaceship Titanic Kaggle Competition
# ### SBX AI/ML Bootcamp | Team: Aida, Abeer

# %% [markdown]
# **Project Overview:**
# Purpose: Apply classical machine learning skills (linear regression, logistic regression, K-Means) to a real-world dataset. Develop strong documentation and model validation skills through a replication exercise.
#
# **Competition Story:** Welcome to the year 2912, where the Spaceship Titanic (an interstellar passenger liner) collided with a spacetime anomaly. Almost half of the 13,000 passengers were transported to an alternate dimension. Your mission: predict which passengers were transported using records recovered from the ship's damaged computer system.
#
# **Target Variable:** Transported (True/False) - whether passenger was transported to alternate dimension
#
# **Goal:** For the SBX Offsite on June 20th, each team will give a short presentation on Assignment 1. Each presentation must cover:
# - Business Context: Explain the problem in non-technical, business language
# - Key Insights: What patterns did you find in the data?
# - Feature Engineering: What features did you create and why?
# - Model Overview: How does your model work? (explain in simple terms)
# - Results: Model performance metrics and Kaggle leaderboard score
# - Key Learnings: What did you learn from this project?
#
# Libraries used (as of May 29):
# - pandas
# - numpy
# - matlotlib
# - sklearn

# %%
# Import libraries

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, r2_score
